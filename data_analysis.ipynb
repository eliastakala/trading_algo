# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tesla_flattened_data.csv')

# %%
df
# Out:
#             Date  Adj Close TSLA  Close TSLA   High TSLA    Low TSLA  \
# 0     2020-01-02       28.684000   28.684000   28.713333   28.114000
# 1     2020-01-03       29.534000   29.534000   30.266666   29.128000
# 2     2020-01-06       30.102667   30.102667   30.104000   29.333332
# 3     2020-01-07       31.270666   31.270666   31.441999   30.224001
# 4     2020-01-08       32.809334   32.809334   33.232666   31.215334
# ...          ...             ...         ...         ...         ...
# 1001  2023-12-22      252.539993  252.539993  258.220001  251.369995
# 1002  2023-12-26      256.609985  256.609985  257.970001  252.910004
# 1003  2023-12-27      261.440002  261.440002  263.339996  257.519989
# 1004  2023-12-28      253.179993  253.179993  265.130005  252.710007
# 1005  2023-12-29      248.479996  248.479996  255.190002  247.429993
#
#        Open TSLA  Volume TSLA
# 0      28.299999    142981500
# 1      29.366667    266677500
# 2      29.364668    151995000
# ...

# %%
#visualize close and adjusted close prices
plt.figure(figsize=(16,8))
plt.title('Tesla')
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(df['Close TSLA'])
plt.plot(df['Adj Close TSLA'])
plt.legend(['Close', 'Adj Close'], loc='upper left')
